# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatamishra79-svg/AI-Social-Media-Content/blob/main/AI_Social_Media_Content.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 AI Social Media Content Generator using Google Gemini
#
# Welcome to this hands-on masterclass!
#
# In this notebook, we will build an AI-powered Social Media Content Generator using Google Gemini API.
#
# By the end of this session, you'll be able to generate:
# - ✨ LinkedIn Posts
# - 📸 Instagram Captions
# - 🏷️ Trending Hashtags
# - 📅 Weekly Content Calendars
# - 📢 Call-to-Action Statements
#
# We'll also learn:
# - ✅ Generative AI
# - ✅ Prompt Engineering
# - ✅ Google Gemini API
# - ✅ Python Integration
# - ✅ Building Real-World AI Applications

# %% [markdown]
#            AI Social Media Content Generator
#
#          👤 User Input
#                 │
#                 ▼
#       🧠 Prompt Engineering
#                 │
#                 ▼
#         🤖 Google Gemini
#                 │
#       ┌─────────┴─────────┐
#       ▼         ▼         ▼
#   📝 Content  🏷️ Tags  📣 CTA
#                 │
#                 ▼
#       🎨 AI Image Prompt
#                 │
#                 ▼
#          🖼️ Final Creative

# %% [markdown]
# ## Step 1: Install Google Gemini SDK
#
# First, we'll install the Google Gemini SDK.
#
# This library enables our Python program to communicate with Google's Gemini AI models.

# %%
# Install Google Gemini SDK

# !pip install -q google-genai

# %% [markdown]
# ## Step 2: Connect to Google Gemini
#
# To access Gemini models, we need to authenticate using an API key.
#
# Think of the API key as a secure password that allows our application to communicate with Google's AI services.

# %%
from google import genai

client = genai.Client(api_key="YOUR_GEMINI_API_KEY")

print("Connected Successfully!")
# Out:
# Connected Successfully!

# %%
models = client.models.list()

for model in models:
    print(model.name)
    break
# Out:
# models/gemini-2.5-flash

# %% [markdown]
# ## Step 3: Collect User Inputs
#
# Now we'll collect the details from the user.
#
# These inputs will help our AI generate personalized social media content based on:
# - Topic
# - Platform
# - Tone
# - Target Audience
# - Content Type

# %%
topic = input("Enter the topic: ")

platform = input("Choose platform (LinkedIn/Instagram/X): ")

tone = input("Choose tone (Professional/Friendly/Funny): ")

audience = input("Target audience: ")

content_type = input("Content type (Post/Caption/Carousel): ")
# Out:
# Enter the topic: Online Leaning
# Choose platform (LinkedIn/Instagram/X): Instagram
# Choose tone (Professional/Friendly/Funny): Friendly
# Target audience: Students and Working Professionals
# Content type (Post/Caption/Carousel): Post

# %% [markdown]
# ## Step 4: Create the AI Prompt
#
# This is the most important step.
#
# Here, we'll combine all the user inputs into a well-structured prompt.
#
# The better the prompt, the better the AI-generated content.

# %%
prompt = f"""
You are an expert Social Media Content Creator.

Generate high-quality content based on the following details.

Topic: {topic}
Platform: {platform}
Tone: {tone}
Target Audience: {audience}
Content Type: {content_type}

Return the output in the following format only:

## 📢 Social Media Post
(Write one engaging post)

## 🏷️ Hashtags
(Generate exactly 5 trending hashtags)

## 📣 Call-To-Action
(Write one engaging CTA)

## 💡 Next Content Idea
(Suggest one related content idea)

Keep the language engaging, concise, and platform-specific.
"""

# %% [markdown]
# ## Step 5: Generate Content using Google Gemini
#
# Now that our prompt is ready, we'll send it to the Gemini AI model.
#
# The model will understand our instructions and generate high-quality social media content based on the user's inputs.

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

# %% [markdown]
# ## Step 6: Display the Generated Content
#
# Let's display the AI-generated social media content.

# %%
print(response.text)
# Out:
# ## 📢 Social Media Post
# Hey awesome learners! 👋 Ever feel like there aren't enough hours in the day to chase your goals AND fit in learning new things? We totally get it! That's where online learning swoops in like a superhero! 🦸‍♀️
#
# Whether you're a student juggling classes and a side hustle, or a working professional keen to upskill without disrupting your routine, online platforms offer unparalleled flexibility and a world of knowledge right at your fingertips. Imagine learning a new language, mastering a software, or even getting a certification – all from your favorite cozy spot! 🛋️✨
#
# It's about empowering YOU to take control of your education and career path, on your own terms. So, what skill are you ready to conquer next? Let's unlock our potential together! 🚀
#
# ## 🏷️ Hashtags
# #OnlineLearning #Elearning #LifelongLearning #Upskill #StudySmart
#
# ## 📣 Call-To-Action
# What's one skill you're excited to learn online this year? Share in the comments below! 👇
#
# ## 💡 Next Content Idea
# A carousel post detailing "Top 5 Free Online Learning Platforms You Need to Check Out!"

# %% [markdown]
# ## Step 7: Improve the Content
#
# One of the biggest advantages of Generative AI is that we don't have to start from scratch.
#
# We can ask the AI to improve, rewrite, shorten, or change the tone of previously generated content simply by giving it another prompt.

# %%
improvement_prompt = f"""
Rewrite the following social media content.

Content:

{response.text}

Make it:

- More engaging
- More professional
- More concise
- Add relevant emojis
- Keep it suitable for {platform}
"""

improved_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=improvement_prompt
)

print(improved_response.text)
# Out:
# Here's a rewritten version of your social media content, optimized for engagement, professionalism, conciseness, and Instagram suitability:
#
# ---
#
# ## 📢 Social Media Post
#
# **Juggling commitments while striving for continuous growth? We understand the challenge. 🧠**
#
# Online learning transforms this challenge into an opportunity! 🌐 Gain expertise, upskill for your career, or master new subjects with unparalleled flexibility – all from your preferred environment.
#
# Picture yourself learning a new language 🗣️, mastering cutting-edge software 💻, or earning a certification 📜 – seamlessly fitting into your life, not disrupting it.
#
# It’s about empowering you to take charge of your educational and professional journey, on your terms. Your potential is limitless! ✨
#
# ## 📣 Call-To-Action
#
# Ready to expand your horizons? Tell us: What's one skill you're excited to learn online this year? Share in the comments! 👇
#
# ## 🏷️ Hashtags
#
# #OnlineLearning #Elearning #LifelongLearner #Upskill #CareerDevelopment #StudySmart #Flexibility
#
# ---
#
# ## 💡 Next Content Idea (for internal use)
#
# A carousel post detailing "Top 5 Free Online Learning Platforms You Need to Check Out!"

# %% [markdown]
# ## Step 9: Generate an AI Image Prompt
#
# Great content deserves great visuals!
#
# Let's ask AI to generate a professional image prompt that can be used in AI image generation tools to create social media graphics.

# %%
image_prompt = f"""
You are an expert AI Image Prompt Engineer.

Generate one highly detailed image prompt for the following topic.

Topic: {topic}

Target Audience: {audience}

The image should look professional, modern, attractive, and suitable for posting on {platform}.

Only generate the image prompt.
"""

image_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=image_prompt
)

print(image_response.text)
# Out:
# Ultra-realistic, high-resolution photograph. A diverse individual, appearing to be in their late 20s or early 30s – embodying both a dedicated student and a professional upskiller – is seated comfortably at a pristine, minimalist desk in a sunlit modern home office. The individual wears smart-casual attire (e.g., a tasteful knit sweater or a crisp linen shirt) and is deeply focused on a sleek, silver laptop displaying a clean, blurred interface of an online learning platform. One hand rests on a high-end tablet, possibly for digital note-taking, or holds a premium pen over a stylish, open physical notebook. High-quality, minimalist headphones are subtly worn.
#
# The workspace is bathed in soft, natural daylight streaming from a large window on the left, casting gentle, flattering shadows and creating a warm, inviting glow. The background features a clean, muted wall (soft beige or light grey) with a few thoughtfully placed, vibrant indoor plants (e.g., a small monstera or snake plant) adding a touch of life and freshness. A ceramic coffee or tea mug sits beside the laptop. The overall aesthetic is clean, organized, and tranquil, conveying productivity and intelligence.
#
# The composition utilizes the rule of thirds, with the individual's face and the laptop screen as key focal points. A shallow depth of field softly blurs the background elements, keeping the subject sharp and prominent. The color palette is dominated by warm neutrals (creams, light wood tones, soft grays) with subtle pops of natural green from the plants and the cool blue light emanating from the screen. The lighting is bright, even, and aspirational. Shot at eye-level, slightly wide angle to capture the modern environment, suitable for an Instagram feed post (e.g., 4:3 or 1:1 aspect ratio). The mood is calm, focused, empowering, and highly professional.

# %%
from PIL import Image

image = Image.open("/content/sample_data/ChatGPT Image Jul 25, 2026, 01_48_05 PM.png")

# %% [markdown]
# ## Step 12: Analyze the Generated Image using Gemini
#
# Generative AI is not limited to text generation.
#
# Gemini is a multimodal AI model, which means it can understand both text and images.
#
# Let's upload our generated image and ask Gemini to analyze whether it matches the social media content we created.

# %%
analysis_prompt = f"""
You are an expert social media marketing consultant.

Analyze this image based on the following details.

Topic: {topic}

Platform: {platform}

Target Audience: {audience}

Please answer:

1. Does this image match the topic?
2. Is it suitable for {platform}?
3. What emotions does it convey?
4. What could be improved?
5. Give the image a rating out of 10.
"""

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        analysis_prompt,
        image
    ]
)

print(response.text)
# Out:
# As an expert social media marketing consultant, here's my analysis of the image for Instagram, targeting students and working professionals on the topic of Online Learning:
#
# ---
#
# ### Image Analysis: Online Learning for Instagram
#
# **1. Does this image match the topic (Online Learning)?**
# **Yes, perfectly.** The image clearly depicts an individual engaged in online learning. We see a laptop displaying a video lecture (with a speaker/instructor visible) and content related to "Supply and Demand," alongside a tablet showing "Market Equilibrium" notes and diagrams. The person is actively taking notes in a physical notebook, which is a key aspect of effective learning. The setup, featuring multiple screens and a dedicated study space, strongly communicates the essence of modern online education.
#
# **2. Is it suitable for Instagram?**
# **Highly suitable.**
# *   **Aesthetics:** The image is beautifully composed, well-lit, and has a clean, modern aesthetic that performs very well on Instagram. The color palette is natural and calming.
# *   **Clarity:** The focal points (the learner, laptop, tablet, notebook) are all clear and easily discernible, even on a smaller screen.
# *   **Relatability:** The scene resonates strongly with both students (university, college) and working professionals (upskilling, certifications, continued education) who engage in remote or online learning. The organized, comfortable study environment is aspirational yet achievable.
# *   **Engagement Potential:** It tells a story of focused productivity and effective learning, which is likely to attract likes, comments, and saves from the target audience.
#
# **3. What emotions does it convey?**
# The image conveys several positive emotions:
# *   **Focus & Productivity:** The individual is engrossed in their work, actively taking notes, symbolizing dedication and effective learning.
# *   **Calm & Serenity:** The tidy desk, natural light from the window, the plant, and the warm cup of tea create a peaceful and conducive learning environment.
# *   **Aspiration & Achievement:** It presents an ideal, organized, and effective way to engage with online education, potentially inspiring viewers to achieve similar levels of focus and success.
# *   **Modernity & Efficiency:** The use of multiple devices (laptop and tablet) highlights a contemporary and efficient approach to learning.
# *   **Comfort & Flexibility:** The home-like setting suggests the comfort and flexibility that online learning offers.
#
# **4. What could be improved?**
# *   **Human Connection:** While the focus on the task is good, the lack of a clear view of the person's face or a subtle positive expression (e.g., a slight smile of understanding) might limit direct emotional connection. A slightly more angled shot that reveals a hint of their facial expression could add more relatability.
# *   **Dynamic Element:** The scene is very static. While it conveys calm, a very subtle hint of interaction (e.g., the person's hand hovering over the tablet screen, or typing on the keyboard) could add a touch more dynamism without losing the sense of focus.
# *   **Branding Opportunities:** If this image is meant to promote a specific online learning platform or brand, there are no visible brand elements. Subtle inclusion of a logo on the laptop screen or a branded accessory could be considered.
# *   **Content Specificity (Optional):** While "Supply and Demand" is generic enough, for a specific campaign, the content on the screens could be tailored to a particular subject or course that the platform offers, making it even more targeted.
#
# **5. Give the image a rating out of 10.**
# **Rating: 9/10**
#
# This is an excellent image for the stated purpose. It perfectly aligns with the topic, is visually appealing and highly suitable for Instagram, and conveys strong positive emotions. The production quality is high. The potential improvements are minor tweaks that would take it from "excellent" to "near-perfect," but they don't detract significantly from its current effectiveness.

# %%
from IPython.display import Markdown, display

display(Markdown(improved_response.text))
display(image)
# Out:
# Here's a rewritten version of your social media content, optimized for engagement, professionalism, conciseness, and Instagram suitability:
#
# ---
#
# ## 📢 Social Media Post
#
# **Juggling commitments while striving for continuous growth? We understand the challenge. 🧠**
#
# Online learning transforms this challenge into an opportunity! 🌐 Gain expertise, upskill for your career, or master new subjects with unparalleled flexibility – all from your preferred environment.
#
# Picture yourself learning a new language 🗣️, mastering cutting-edge software 💻, or earning a certification 📜 – seamlessly fitting into your life, not disrupting it.
#
# It’s about empowering you to take charge of your educational and professional journey, on your terms. Your potential is limitless! ✨
#
# ## 📣 Call-To-Action
#
# Ready to expand your horizons? Tell us: What's one skill you're excited to learn online this year? Share in the comments! 👇
#
# ## 🏷️ Hashtags
#
# #OnlineLearning #Elearning #LifelongLearner #Upskill #CareerDevelopment #StudySmart #Flexibility
#
# ---
#
# ## 💡 Next Content Idea (for internal use)
#
# A carousel post detailing "Top 5 Free Online Learning Platforms You Need to Check Out!"
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1122x1402>
